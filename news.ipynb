https://www.givenchybeauty.com/us/legal/privacy-policy.html

Terms and conditions
https://www.givenchybeauty.com/us/legal/terms-conditions.html

Terms of sales
https://www.givenchybeauty.com/us/legal/terms-conditions.html

Remember to sort your packaging
_____________________________________________________________________________________________

Givenchy is responsible for processing your personal data. You have previously consented to the collection of your data for sending communications about our products and services. In accordance with EU Regulation 2016/679 of April 27, 2016 relating to the protection of personal data (RGPD), you have the right to consult, modify and delete any data concerning you. You can learn about all of your rights by reading our privacy policy. You can exercise these rights at any time by sending us an email to dpo@parfumsgivenchy.fr. You can also ask to no longer receive communications about our products and services.

If you want to stop receiving emails from Givenchy, click here.
$unsubUrl$

the above is the look and here is the detailed explanaiton of the newsletter:
Header:

Givenchy logo in the center, linked to the Givenchy Beauty website (https://www.givenchybeauty.com/us).
Horizontal navigation bar with links to different sections of the Givenchy Beauty website: New, Fragrance, Makeup, Skincare.
Hero Section:

Large banner image with the text "FALL IN LOVE".
Text block explaining the theme (Valentine's Day Gift Guide) and prompting users to explore.
Centered button linked to the Givenchy Beauty website, inviting users to "EXPLORE GIFTS".
Product Section 1:

Three columns displaying product images with titles:
Left column: "PRISME LIBRE LOOSE POWDER"
Center column (bolded text): "FLAWLESS BEAUTY ICONS"
Text block describing the product and its benefits.
Centered button linked to the Givenchy Beauty website, inviting users to "SHOP NOW".
Main Content Section:

Bolded text headline: "FIND THE PERFECT GIFT"
Product Section 2:

Three-column layout showcasing different gift categories:
Left column: "FRAGRANCE GIFTS"
Center column: "MAKEUP GIFTS"
Right column: "LIMITED EDITION GIFT SETS"
Each column has a product image and a button linked to the Givenchy Beauty website, inviting users to "SHOP NOW".
Product Section 3:

Two columns:
Left column: Image (presumably showcasing online exclusive services)
Right column (bolded text): "UNFORGETTABLE EXPERIENCE" with details about the service (complimentary personalization)
Centered button linked to the Givenchy Beauty website, inviting users to "SHOP NOW".
Promotional Section:

Large banner image with text "UNLOCK YOUR PRIVILEGE".
Text block explaining a special offer with a purchase.
Centered button linked to the Givenchy Beauty website, inviting users to "SHOP NOW".
Social Media Section (Desktop View Only):

Five icons linked to Givenchy Beauty's social media profiles (Facebook, Youtube, Instagram, TikTok, Pinterest).
Text "FOLLOW US" displayed above the icons.
Footer Section:

Links to various sections of the Givenchy Beauty website: FAQ, Contact, Newsletter Unsubscribe, Accessibility.
Links to additional Givenchy websites: Career, Press.
"""

# %%
from langchain.prompts import ChatPromptTemplate
prompt_template="""

You are a coding expert in HTML.
Given a layout description in text {text}, you will generate HTML code that includes links to images. Ensure that the HTML code uses the exact content provided in the layout and maintains the intended look of the website. Follow these guidelines:

Newsletter Layout:

Use only the <table> tag for newsletters.
Styling:

Desktop View: Implement styling using inline CSS only.
Mobile View: Implement styling using internal CSS within a <style> tag and use !important to overwrite desktop styles.
Headings and Text:

Do not use <h1> to <h6> tags for headings.
Do not use <p> tags for text content.
Use the <font> tag or the style attribute to specify fonts for all text.
Buttons:

Do not use the <button> tag.
Use a div with a background color to simulate a button.
Images:

Always specify width and height attributes for <img> tags based on the actual dimensions of the images.
Include the title attribute and set display:block style for <img> tags.
Table Layout:

Do not use padding in <td> tags.
Ensure each element (e.g., logo, menu, CTA) is in a separate row in the table.
Each column should have align and valign properties.
HTML Version:

Use HTML4 Doctype.
Provide the HTML code in a well-formatted manner that adheres to these guidelines. Ensure the website's appearance is maintained as per the layout description.

 """

# %%
c=""""

<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd"><html><head>  <meta http-equiv="Content-Type" content="text/html; charset=utf-8">  <meta name="viewport" content="width=device-width, initial-scale=1.0">  <title>PERFECT GIFT FOR YOUR LOVED ONES</title>  <style type="text/css">    @media only screen and (max-width: 600px) {      .wrapper {width: 100% !important;}      .column {display: block !important; width: 100% !important;}      .mobile-hidden {display: none !important;}      .mobile-center {text-align: center !important;}      .mobile-padding {padding: 10px !important;}    }  </style></head><body style="margin:0; padding:0; background-color:#F2F2F2;"><table border="0" cellpadding="0" cellspacing="0" width="100%">  <tr>    <td align="center" valign="top">      <table class="wrapper" border="0" cellpadding="0" cellspacing="0" width="600">        <!-- Header -->        <tr>          <td align="center" valign="top" style="padding: 20px 0;">            <a href="https://www.givenchybeauty.com/us" target="_blank">              <img src="logo.jpg" alt="GIVENCHY" width="200" height="50" border="0" style="display:block;">            </a>          </td>        </tr>        <!-- Navigation -->        <tr>          <td align="center" valign="top" style="padding: 10px 0; background-color: #000000;">            <table border="0" cellpadding="0" cellspacing="0" width="100%">              <tr>                <td align="center" valign="top">                  <a href="https://www.givenchybeauty.com/us/best-sellers/best-sellers/" target="_blank" style="color: #FFFFFF; text-decoration: none; padding: 0 10px; font-family: Arial, sans-serif; font-size: 14px;">NEW</a>                  <a href="https://www.givenchybeauty.com/us/fragrance-1/" target="_blank" style="color: #FFFFFF; text-decoration: none; padding: 0 10px; font-family: Arial, sans-serif; font-size: 14px;">FRAGRANCE</a>                  <a href="https://www.givenchybeauty.com/us/makeup/" target="_blank" style="color: #FFFFFF; text-decoration: none; padding: 0 10px; font-family: Arial, sans-serif; font-size: 14px;">MAKEUP</a>                  <a href="https://www.givenchybeauty.com/us/skincare/" target="_blank" style="color: #FFFFFF; text-decoration: none; padding: 0 10px; font-family: Arial, sans-serif; font-size: 14px;">SKINCARE</a>                </td>              </tr>            </table>          </td>        </tr>        <!-- Hero Section -->        <tr>          <td align="center" valign="top" style="background-color: #F2F2F2;">            <table border="0" cellpadding="0" cellspacing="0" width="100%">              <tr>                <td align="center" valign="top">                  <img src="giv_us_vday_gift_mob_0223_01.jpg" alt="FALL IN LOVE" width="600" height="400" border="0" style="display:block;">                </td>              </tr>              <tr>                <td align="center" valign="top" style="padding: 20px;">                  <font style="font-family: Arial, sans-serif; font-size: 16px; color: #333333;">                    Celebrate your special someone or yourself with a gift like no other.<br>                    Discover the Valentine\'s Day Gift Guide featuring coveted beauty and fragrance essentials.                  </font>                </td>              </tr>              <tr>                <td align="center" valign="top" style="padding: 20px 0;">                  <div style="background-color: #000000; padding: 10px 20px;">                    <a href="https://www.givenchybeauty.com/us" target="_blank" style="color: #FFFFFF; text-decoration: none; font-family: Arial, sans-serif; font-size: 16px;">EXPLORE GIFTS</a>                  </div>                </td>              </tr>            </table>          </td>        </tr>        <!-- Product Section 1 -->        <tr>          <td align="center" valign="top" style="padding: 20px 0;">            <table border="0" cellpadding="0" cellspacing="0" width="100%">              <tr>                <td align="center" valign="top">                  <img src="pow.jpg" alt="PRISME LIBRE LOOSE POWDER" width="200" height="200" border="0" style="display:block;">                </td>              </tr>              <tr>                <td align="center" valign="top" style="padding: 20px;">                  <font style="font-family: Arial, sans-serif; font-size: 24px; color: #333333; font-weight: bold;">FLAWLESS BEAUTY ICONS</font>                  <br><br>                  <font style="font-family: Arial, sans-serif; font-size: 16px; color: #333333;">                    Explore iconic beauty icons like the Prisme Libre Loose Powder, designed to keep your complexion set, mattified, and illuminated for all day coverage.                  </font>                </td>              </tr>              <tr>                <td align="center" valign="top" style="padding: 20px 0;">                  <div style="background-color: #000000; padding: 10px 20px;">                    <a href="https://www.givenchybeauty.com/us" target="_blank" style="color: #FFFFFF; text-decoration: none; font-family: Arial, sans-serif; font-size: 16px;">SHOP NOW</a>                  </div>                </td>              </tr>            </table>          </td>        </tr>        <!-- Main Content Section -->        <tr>          <td align="center" valign="top" style="padding: 20px 0;">            <font style="font-family: Arial, sans-serif; font-size: 24px; color: #333333; font-weight: bold;">FIND THE PERFECT GIFT</font>          </td>        </tr>        <!-- Product Section 2 -->        <tr>          <td align="center" valign="top" style="padding: 20px 0;">            <table border="0" cellpadding="0" cellspacing="0" width="100%">              <tr>                <td class="column" align="center" valign="top" width="33.33%" style="padding: 0 10px;">                  <img src="f.jpg" alt="FRAGRANCE GIFTS" width="180" height="180" border="0" style="display:block;">                  <br>                  <div style="background-color: #000000; padding: 10px 20px;">                    <a href="https://www.givenchybeauty.com/us" target="_blank" style="color: #FFFFFF; text-decoration: none; font-family: Arial, sans-serif; font-size: 16px;">SHOP NOW</a>                  </div>                </td>                <td class="column" align="center" valign="top" width="33.33%" style="padding: 0 10px;">                  <img src="m.jpg" alt="MAKEUP GIFTS" width="180" height="180" border="0" style="display:block;">                  <br>                  <div style="background-color: #000000; padding: 10px 20px;">                    <a href="https://www.givenchybeauty.com/us" target="_blank" style="color: #FFFFFF; text-decoration: none; font-family: Arial, sans-serif; font-size: 16px;">SHOP NOW</a>                  </div>                </td>                <td class="column" align="center" valign="top" width="33.33%" style="padding: 0 10px;">                  <img src="l.png" alt="LIMITED EDITION GIFT SETS" width="180" height="180" border="0" style="display:block;">                  <br>                  <div style="background-color: #000000; padding: 10px 20px;">                    <a href="https://www.givenchybeauty.com/us" target="_blank" style="color: #FFFFFF; text-decoration: none; font-family: Arial, sans-serif; font-size: 16px;">SHOP NOW</a>                  </div>                </td>              </tr>            </table>          </td>        </tr>        <!-- Product Section 3 -->        <tr>          <td align="center" valign="top" style="padding: 20px 0;">            <table border="0" cellpadding="0" cellspacing="0" width="100%">              <tr>                <td class="column" align="center" valign="top" width="50%">                  <img src="u.jpg" alt="Online Exclusive Services" width="280" height="280" border="0" style="display:block;">                </td>                <td class="column" align="center" valign="top" width="50%" style="padding: 0 20px;">                  <font style="font-family: Arial, sans-serif; font-size: 24px; color: #333333; font-weight: bold;">UNFORGETTABLE EXPERIENCE</font>                  <br><br>                  <font style="font-family: Arial, sans-serif; font-size: 16px; color: #333333;">                    Add a personal touch to your gifts with complimentary personalization. Include a special note to your gift specially paired with our couture boxes for an unforgettable gifting experience.                  </font>                  <br><br>                  <div style="background-color: #000000; padding: 10px 20px;">                    <a href="https://www.givenchybeauty.com/us" target="_blank" style="color: #FFFFFF; text-decoration: none; font-family: Arial, sans-serif; font-size: 16px;">SHOP NOW</a>                  </div>                </td>              </tr>            </table>          </td>        </tr>        <!-- Promotional Section -->        <tr>          <td align="center" valign="top" style="padding: 20px 0;">            <table border="0" cellpadding="0" cellspacing="0" width="100%">              <tr>                <td align="center" valign="top">                  <img src="un.jpg" alt="UNLOCK YOUR PRIVILEGE" width="600" height="300" border="0" style="display:block;">                </td>              </tr>              <tr>                <td align="center" valign="top" style="padding: 20px;">                  <font style="font-family: Arial, sans-serif; font-size: 16px; color: #333333;">                    Receive a complimentary Gentleman Society travel spray and a Gentleman Eau de Parfum Boisée Miniature with any purchase of 65€ or more.                  </font>                  <br><br>                  <div style="background-color: #000000; padding: 10px 20px;">                    <a href="https://www.givenchybeauty.com/us" target="_blank" style="color: #FFFFFF; text-decoration: none; font-family: Arial, sans-serif; font-size: 16px;">SHOP NOW</a>                  </div>                </td>              </tr>            </table>          </td>        </tr>        <!-- Social Media Section (Desktop Only) -->        <tr class="mobile-hidden">          <td align="center" valign="top" style="padding: 20px 0;">            <font style="font-family: Arial, sans-serif; font-size: 16px; color: #333333;">FOLLOW US</font>            <br><br>            <table border="0" cellpadding="0" cellspacing="0">              <tr>                <td align="center" valign="top" style="padding: 0 10px;">                  <a href="https://www.facebook.com/givenchybeauty/" target="_blank">                    <img src="facebook.jpg" alt="Facebook" width="30" height="30" border="0" style="display:block;">                  </a>                </td>                <td align="center" valign="top" style="padding: 0 10px;">                  <a href="https://www.youtube.com/channel/UCKls9SbX37kXKfZIPCmcIAg" target="_blank">                    <img src="you.jpg" alt="Youtube" width="30" height="30" border="0" style="display:block;">                  </a>                </td>                <td align="center" valign="top" style="padding: 0 10px;">                  <a href="https://www.instagram.com/givenchybeauty/?hl=en" target="_blank">                    <img src="insta.jpg" alt="Instagram" width="30" height="30" border="0" style="display:block;">                  </a>                </td>                <td align="center" valign="top" style="padding: 0 10px;">                  <a href="https://www.tiktok.com/@givenchybeauty?" target="_blank">                    <img src="tik.jpg" alt="TIK TOK" width="30" height="30" border="0" style="display:block;">                  </a>                </td>                <td align="center" valign="top" style="padding: 0 10px;">                  <a href="https://www.pinterest.com/givenchybeauty/" target="_blank">                    <img src="pin.jpg" alt="PINTEREST" width="30" height="30" border="0" style="display:block;">                  </a>                </td>              </tr>            </table>          </td>        </tr>        <!-- Footer Section -->        <tr>          <td align="center" valign="top" style="padding: 20px; background-color: #000000;">            <table border="0" cellpadding="0" cellspacing="0" width="100%">              <tr>                <td align="center" valign="top" style="padding: 10px;">                  <font style="font-family: Arial, sans-serif; font-size: 14px; color: #FFFFFF;">                    <a href="https://www.givenchybeauty.com/us/customer-services/faq.html" target="_blank" style="color: #FFFFFF; text-decoration: none;">FAQ</a> |                    <a href="https://www.givenchybeauty.com/us/contactus" target="_blank" style="color: #FFFFFF; text-decoration: none;">Contact</a> |                    <a href="https://www.givenchybeauty."></a>




"""

# %%
p=""""

I have an HTML code {code} that needs some modifications based on the following requirements. Please make the necessary changes to the HTML code:

Do not use padding in the <td> tag.
Use a separate row for product images and CTA (Call to Action) buttons.
Correct the width and height of social icons.
For the mobile layout, overwrite the styles in a media query using !important.

return  the HTML code in a well-formatted manner that adheres to these guidelines





"""

# %%
prompt=ChatPromptTemplate.from_template(p)
build = prompt | llm
output_1 = build.invoke({"code":c})
response=output_1
response
# Out:
# AIMessage(content='Here\'s the modified HTML code based on the given requirements:\n\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\n<html>\n<head>\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n  <title>PERFECT GIFT FOR YOUR LOVED ONES</title>\n  <style type="text/css">\n    @media only screen and (max-width: 600px) {\n      .wrapper {width: 100% !important;}\n      .column {display: block !important; width: 100% !important;}\n      .mobile-hidden {display: none !important;}\n      .mobile-center {text-align: center !important;}\n      .mobile-padding {padding: 10px !important;}\n      td {padding: 0 !important;}\n    }\n  </style>\n</head>\n<body style="margin:0; padding:0; background-color:#F2F2F2;">\n<table border="0" cellpadding="0" cellspacing="0" width="100%">\n  <tr>\n    <td align="center" valign="top">\n      <table clas
# ...
